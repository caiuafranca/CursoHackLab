# %%
import pandas as pd
#import requests

# %%
#resposta = requests.get('http://dados.natal.br/api/3/action/datastore_search')
df = pd.read_csv('dados_transporte_natal.csv', sep=';', encoding='cp1252')

# %%
#df = pd.DataFrame(resposta.json()['dados'])
df.describe
# Out:
# <bound method NDFrame.describe of     Mês            Empresa  Linha  Estudante_Cartao  Estudante_BT  \
# 0     1          CONCEIÇÃO     21             14433          4640
# 1     1          CONCEIÇÃO     22              2099           842
# 2     1          CONCEIÇÃO     30             10095          2912
# 3     1          CONCEIÇÃO     31             10282          3142
# 4     1          CONCEIÇÃO     41              7218          1673
# 5     1          CONCEIÇÃO     59              8788          3669
# 6     1          CONCEIÇÃO     63             24601          7013
# 7     1          CONCEIÇÃO     71             10033          3718
# 8     1          CONCEIÇÃO     76              3105           935
# 9     1          CONCEIÇÃO     83              4775          1898
# 10    1          CONCEIÇÃO    411              6577          1635
# 11    1          CONCEIÇÃO    587              1125             3
# 12    1          CONCEIÇÃO    599              7385          1764
# ...

# %%
#Quantidade de Linhas
df['Empresa'].value_counts()
# Out:
# GUANABARA - URB      36
# CONCEIÇÃO            19
# SANTA MARIA - URB    17
# REUNIDAS             12
# DUNAS - URB           6
# VIA SUL - URB         4
# Name: Empresa, dtype: int64

# %%
df[df['Empresa'] == 'SANTA MARIA - URB']
# Out:
#     Mês            Empresa  Linha  Estudante_Cartao  Estudante_BT  \
# 73    1  SANTA MARIA - URB     24             13291          4304
# 74    1  SANTA MARIA - URB     34              4761          1418
# 75    1  SANTA MARIA - URB     36              5514          1949
# 76    1  SANTA MARIA - URB     37             17916          6228
# 77    1  SANTA MARIA - URB     38             26900          8540
# 78    1  SANTA MARIA - URB     39             12985          3068
# 79    1  SANTA MARIA - URB     44             11110          3893
# 80    1  SANTA MARIA - URB     46             14058          5483
# 81    1  SANTA MARIA - URB     48              5669          2160
# 82    1  SANTA MARIA - URB     54             17027          6555
# 83    1  SANTA MARIA - URB     56              4528          1872
# 84    1  SANTA MARIA - URB     66              5724          2530
# 85    1  SANTA MARIA - URB     83              5516          2226
# ...
