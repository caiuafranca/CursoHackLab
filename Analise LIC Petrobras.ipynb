# %%
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv('detalhamento.csv')

# %%
df
# Out:
#                                                   UASG  \
# 0    153229: MEC-ESCOLA AGROTECNICA FED./COLOR.DO O...
# 1    153229: MEC-ESCOLA AGROTECNICA FED./COLOR.DO O...
# 2    153229: MEC-ESCOLA AGROTECNICA FED./COLOR.DO O...
# 3    153229: MEC-ESCOLA AGROTECNICA FED./COLOR.DO O...
# 4    153229: MEC-ESCOLA AGROTECNICA FED./COLOR.DO O...
# 5    153229: MEC-ESCOLA AGROTECNICA FED./COLOR.DO O...
# 6    153229: MEC-ESCOLA AGROTECNICA FED./COLOR.DO O...
# 7    153229: MEC-ESCOLA AGROTECNICA FED./COLOR.DO O...
# 8    153229: MEC-ESCOLA AGROTECNICA FED./COLOR.DO O...
# 9    153229: MEC-ESCOLA AGROTECNICA FED./COLOR.DO O...
# 10   153229: MEC-ESCOLA AGROTECNICA FED./COLOR.DO O...
# 11   153229: MEC-ESCOLA AGROTECNICA FED./COLOR.DO O...
# 12   153229: MEC-ESCOLA AGROTECNICA FED./COLOR.DO O...
# 13   153229: MEC-ESCOLA AGROTECNICA FED./COLOR.DO O...
# 14   153229: MEC-ESCOLA AGROTECNICA FED./COLOR.DO O...
# 15   153229: MEC-ESCOLA AGROTECNICA FED./COLOR.DO O...
# ...
